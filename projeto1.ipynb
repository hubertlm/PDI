# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
im = Image.open("Images/Fig0819(a).tif")

# Imagem original escolhida
plt.axis("off") 
plt.imshow(im, cmap = 'gray')
plt.show()
